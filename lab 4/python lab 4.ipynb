# %%
# !pip -q install python-telegram-bot python-dotenv nest-asyncio

import os
import csv
import sqlite3
import logging
from datetime import datetime, timezone

import nest_asyncio
from dotenv import load_dotenv
from zoneinfo import ZoneInfo

from telegram import Update
from telegram.ext import (
    Application,
    CommandHandler,
    MessageHandler,
    ConversationHandler,
    ContextTypes,
    filters
)

# %%
import os

os.environ["BOT_TOKEN"] = "тут когда-то был токен)"
os.environ["CURRENCY"] = "RUB"
os.environ["DATABASE_PATH"] = "bot.db"
os.environ["TIMEZONE"] = "Europe/Moscow"
os.environ["ADMIN_ID"] = "0"

print("BOT_TOKEN set:", bool(os.getenv("BOT_TOKEN")))
print("CURRENCY:", os.getenv("CURRENCY"))
print("TIMEZONE:", os.getenv("TIMEZONE"))
# Out:
# BOT_TOKEN set: True
# CURRENCY: RUB
# TIMEZONE: Europe/Moscow

# %%
load_dotenv()

class Config:
    BOT_TOKEN = os.getenv("BOT_TOKEN")
    ADMIN_ID = int(os.getenv("ADMIN_ID", "0"))
    DATABASE_PATH = os.getenv("DATABASE_PATH", "bot.db")
    CURRENCY = os.getenv("CURRENCY", "RUB")
    TIMEZONE = os.getenv("TIMEZONE", "Europe/Moscow")

    WEBHOOK_URL = os.getenv("WEBHOOK_URL", "")
    WEBHOOK_PORT = int(os.getenv("WEBHOOK_PORT", "8443"))

    @classmethod
    def validate(cls):
        if not cls.BOT_TOKEN:
            raise ValueError("BOT_TOKEN не установлен (.env или os.environ)")

Config.validate()
LOCAL_TZ = ZoneInfo(Config.TIMEZONE)

logging.basicConfig(
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    level=logging.INFO
)
logger = logging.getLogger("expenses-bot")
logger.info("Config loaded. DB=%s TZ=%s CUR=%s", Config.DATABASE_PATH, Config.TIMEZONE, Config.CURRENCY)
# Out:
# 2026-01-21 14:42:59,020 - expenses-bot - INFO - Config loaded. DB=bot.db TZ=Europe/Moscow CUR=RUB

# %%
class DatabaseManager:
    def __init__(self, db_path: str = Config.DATABASE_PATH):
        self.db_path = db_path
        self.init_database()

    def get_connection(self):
        conn = sqlite3.connect(self.db_path)
        conn.row_factory = sqlite3.Row
        return conn

    def init_database(self):
        with self.get_connection() as conn:
            conn.execute("""
                CREATE TABLE IF NOT EXISTS users (
                    user_id INTEGER PRIMARY KEY,
                    username TEXT,
                    first_name TEXT,
                    last_name TEXT,
                    language_code TEXT,
                    is_bot BOOLEAN,
                    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
                    last_activity TIMESTAMP DEFAULT CURRENT_TIMESTAMP
                )
            """)

            conn.execute("""
                CREATE TABLE IF NOT EXISTS messages (
                    message_id INTEGER PRIMARY KEY AUTOINCREMENT,
                    user_id INTEGER,
                    text TEXT,
                    message_date TIMESTAMP,
                    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
                    FOREIGN KEY (user_id) REFERENCES users (user_id)
                )
            """)

            conn.execute("""
                CREATE TABLE IF NOT EXISTS expenses (
                    expense_id INTEGER PRIMARY KEY AUTOINCREMENT,
                    user_id INTEGER NOT NULL,
                    amount REAL NOT NULL,
                    category TEXT NOT NULL,
                    note TEXT,
                    created_at_utc INTEGER NOT NULL,
                    FOREIGN KEY (user_id) REFERENCES users (user_id)
                )
            """)
            conn.execute("CREATE INDEX IF NOT EXISTS idx_expenses_user_time ON expenses(user_id, created_at_utc)")

        logger.info("DB initialized: %s", self.db_path)

    def save_user(self, user):
        with self.get_connection() as conn:
            conn.execute("""
                INSERT OR REPLACE INTO users
                (user_id, username, first_name, last_name, language_code, is_bot, last_activity)
                VALUES (?, ?, ?, ?, ?, ?, ?)
            """, (
                user.id, user.username, user.first_name, user.last_name,
                user.language_code, user.is_bot, datetime.now()
            ))

    def save_message(self, user_id: int, text: str, message_date):
        with self.get_connection() as conn:
            conn.execute("""
                INSERT INTO messages (user_id, text, message_date)
                VALUES (?, ?, ?)
            """, (user_id, text, message_date))

    def add_expense(self, user_id: int, amount: float, category: str, note: str):
        ts_utc = int(datetime.now(timezone.utc).timestamp())
        with self.get_connection() as conn:
            conn.execute("""
                INSERT INTO expenses (user_id, amount, category, note, created_at_utc)
                VALUES (?, ?, ?, ?, ?)
            """, (user_id, amount, category, note, ts_utc))

    def get_expenses_between(self, user_id: int, ts_from_utc: int, ts_to_utc: int):
        with self.get_connection() as conn:
            return conn.execute("""
                SELECT expense_id, amount, category, note, created_at_utc
                FROM expenses
                WHERE user_id=? AND created_at_utc>=? AND created_at_utc<?
                ORDER BY created_at_utc DESC
            """, (user_id, ts_from_utc, ts_to_utc)).fetchall()

    def sum_total_between(self, user_id: int, ts_from_utc: int, ts_to_utc: int) -> float:
        with self.get_connection() as conn:
            row = conn.execute("""
                SELECT COALESCE(SUM(amount), 0) AS total
                FROM expenses
                WHERE user_id=? AND created_at_utc>=? AND created_at_utc<?
            """, (user_id, ts_from_utc, ts_to_utc)).fetchone()
        return float(row["total"]) if row else 0.0

    def sum_by_category_between(self, user_id: int, ts_from_utc: int, ts_to_utc: int):
        with self.get_connection() as conn:
            return conn.execute("""
                SELECT category, ROUND(SUM(amount), 2) AS total
                FROM expenses
                WHERE user_id=? AND created_at_utc>=? AND created_at_utc<?
                GROUP BY category
                ORDER BY total DESC
            """, (user_id, ts_from_utc, ts_to_utc)).fetchall()

db = DatabaseManager()
# Out:
# 2026-01-21 14:43:37,951 - expenses-bot - INFO - DB initialized: bot.db

# %%
from datetime import datetime, timezone

def bounds_today():
    now_local = datetime.now(LOCAL_TZ)
    start_local = now_local.replace(hour=0, minute=0, second=0, microsecond=0)
    ts_from = int(start_local.astimezone(timezone.utc).timestamp())
    ts_to = int(datetime.now(timezone.utc).timestamp()) + 1
    title = f"Сегодня ({start_local.date().isoformat()})"
    return ts_from, ts_to, title

def bounds_month():
    now_local = datetime.now(LOCAL_TZ)
    start_local = now_local.replace(day=1, hour=0, minute=0, second=0, microsecond=0)
    ts_from = int(start_local.astimezone(timezone.utc).timestamp())
    ts_to = int(datetime.now(timezone.utc).timestamp()) + 1
    title = f"Месяц ({start_local.strftime('%Y-%m')})"
    return ts_from, ts_to, title

def format_summary(title: str, total: float, by_cat_rows) -> str:
    if total <= 0:
        return f"{title}\n\nПока нет расходов."
    lines = [f"{title}", "", f"Итого: {total:.2f} {Config.CURRENCY}", "", "По категориям:"]
    for r in by_cat_rows:
        lines.append(f"• {r['category']}: {float(r['total']):.2f} {Config.CURRENCY}")
    return "\n".join(lines)

# %%
AMOUNT, CATEGORY, NOTE = range(3)

async def add_start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    await update.message.reply_text("Введите сумму (например 350 или 350.50):")
    return AMOUNT

async def add_amount(update: Update, context: ContextTypes.DEFAULT_TYPE):
    text = (update.message.text or "").strip().replace(",", ".")
    try:
        amount = float(text)
        if amount <= 0:
            raise ValueError
    except ValueError:
        await update.message.reply_text("Нужно число > 0. Попробуй ещё раз:")
        return AMOUNT

    context.user_data["amount"] = amount
    await update.message.reply_text("Введите категорию (еда/такси/дом):")
    return CATEGORY

async def add_category(update: Update, context: ContextTypes.DEFAULT_TYPE):
    cat = (update.message.text or "").strip().lower()
    if not cat:
        await update.message.reply_text("Категория не может быть пустой. Введите категорию:")
        return CATEGORY
    context.user_data["category"] = cat
    await update.message.reply_text("Комментарий (или '-' чтобы пропустить):")
    return NOTE

async def add_note(update: Update, context: ContextTypes.DEFAULT_TYPE):
    note = (update.message.text or "").strip()
    if note == "-":
        note = ""

    user = update.effective_user
    db.save_user(user)
    db.add_expense(user.id, context.user_data["amount"], context.user_data["category"], note)

    msg = f"Добавлено: {context.user_data['amount']:.2f} {Config.CURRENCY} — {context.user_data['category']}"
    if note:
        msg += f" — {note}"

    context.user_data.clear()
    await update.message.reply_text(msg)
    return ConversationHandler.END

async def add_cancel(update: Update, context: ContextTypes.DEFAULT_TYPE):
    context.user_data.clear()
    await update.message.reply_text("Добавление отменено.")
    return ConversationHandler.END

# %%
HELP_TEXT = (
    "Учёт расходов (RUB)\n\n"
    "Команды:\n"
    "/start\n"
    "/help\n"
    "/add — добавить расход (многошагово)\n"
    "/today — за сегодня\n"
    "/month — за месяц\n"
    "/export — CSV за месяц\n"
    "/cancel — отмена /add\n"
)

async def start_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = update.effective_user
    db.save_user(user)
    await update.message.reply_text(f"Привет, {user.first_name}! \n\n{HELP_TEXT}")

async def help_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
    await update.message.reply_text(HELP_TEXT)

async def today_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = update.effective_user
    db.save_user(user)
    ts_from, ts_to, title = bounds_today()
    total = db.sum_total_between(user.id, ts_from, ts_to)
    by_cat = db.sum_by_category_between(user.id, ts_from, ts_to)
    await update.message.reply_text(format_summary(title, total, by_cat))

async def month_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = update.effective_user
    db.save_user(user)
    ts_from, ts_to, title = bounds_month()
    total = db.sum_total_between(user.id, ts_from, ts_to)
    by_cat = db.sum_by_category_between(user.id, ts_from, ts_to)
    await update.message.reply_text(format_summary(title, total, by_cat))

async def export_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = update.effective_user
    db.save_user(user)

    ts_from, ts_to, title = bounds_month()
    rows = db.get_expenses_between(user.id, ts_from, ts_to)

    if not rows:
        await update.message.reply_text("За этот месяц пока нет расходов.")
        return

    filename = f"expenses_{datetime.now(LOCAL_TZ).strftime('%Y_%m')}.csv"
    with open(filename, "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["expense_id", "amount", "currency", "category", "note", "datetime_local"])
        for r in rows:
            dt_local = datetime.fromtimestamp(int(r["created_at_utc"]), tz=timezone.utc).astimezone(LOCAL_TZ)
            w.writerow([r["expense_id"], f"{float(r['amount']):.2f}", Config.CURRENCY, r["category"], r["note"], dt_local.isoformat()])

    await update.message.reply_document(document=open(filename, "rb"), filename=filename, caption=f"Экспорт: {title}")

async def echo_and_save_message(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = update.effective_user
    db.save_user(user)
    db.save_message(user.id, update.message.text, update.message.date)
    await update.message.reply_text("Сообщение сохранено. Для расходов используй /add")

async def error_handler(update: object, context: ContextTypes.DEFAULT_TYPE):
    logger.error("Ошибка: %s", context.error)

# %%
class TelegramBot:
    def __init__(self, token: str):
        self.application = Application.builder().token(token).build()
        self.setup_handlers()

    def setup_handlers(self):
        self.application.add_handler(CommandHandler("start", start_command))
        self.application.add_handler(CommandHandler("help", help_command))
        self.application.add_handler(CommandHandler("today", today_command))
        self.application.add_handler(CommandHandler("month", month_command))
        self.application.add_handler(CommandHandler("export", export_command))

        conv_handler = ConversationHandler(
            entry_points=[CommandHandler("add", add_start)],
            states={
                AMOUNT: [MessageHandler(filters.TEXT & ~filters.COMMAND, add_amount)],
                CATEGORY: [MessageHandler(filters.TEXT & ~filters.COMMAND, add_category)],
                NOTE: [MessageHandler(filters.TEXT & ~filters.COMMAND, add_note)],
            },
            fallbacks=[CommandHandler("cancel", add_cancel)],
        )
        self.application.add_handler(conv_handler)

        self.application.add_handler(
            MessageHandler(filters.TEXT & ~filters.COMMAND, echo_and_save_message)
        )

        self.application.add_error_handler(error_handler)

    def run_polling(self):
        print("Бот запущен (polling)...")
        self.application.run_polling()

# %%
nest_asyncio.apply()

bot = TelegramBot(Config.BOT_TOKEN)
app = bot.application

async def start_bot():
    await app.initialize()
    await app.start()
    await app.updater.start_polling()
    print("Бот запущен. Остановить: await stop_bot()")

async def stop_bot():
    await app.updater.stop()
    await app.stop()
    await app.shutdown()
    print("Бот остановлен")

await start_bot()
# Out:
# 2026-01-21 14:49:36,773 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getMe "HTTP/1.1 200 OK"
# 2026-01-21 14:49:36,776 - telegram.ext.Application - INFO - Application started
# 2026-01-21 14:49:36,831 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/deleteWebhook "HTTP/1.1 200 OK"
# Бот запущен. Остановить: await stop_bot()
# 2026-01-21 14:49:47,160 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:49:57,295 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:50:07,347 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:50:17,468 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:50:27,605 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:50:37,658 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:50:47,738 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:50:57,802 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:51:07,858 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:51:17,988 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:51:20,254 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# /var/folders/mf/ss36h2h159q80w_c2zvxbx3c0000gn/T/ipykernel_11886/1713845618.py:54: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   conn.execute("""
# 2026-01-21 14:51:20,554 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:51:30,379 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:51:40,440 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:51:50,497 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:51:54,386 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:51:54,676 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:52:04,478 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:52:04,888 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:52:05,190 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:52:08,097 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:52:08,202 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:52:11,648 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:52:11,727 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:52:21,786 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:52:31,839 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:52:42,204 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:52:52,300 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:53:00,547 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:53:00,889 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:53:10,612 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:53:20,670 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:53:30,802 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:53:40,868 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:53:50,923 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:54:01,012 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:54:11,066 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:54:21,187 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:54:23,541 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:54:33,604 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:54:39,924 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:54:50,024 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:00,105 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:10,162 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:18,428 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:19,145 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:55:19,861 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:20,028 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:55:23,958 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:24,064 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:55:26,005 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:26,176 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:55:28,681 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:38,806 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:48,868 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:58,979 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:55:59,091 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:56:01,129 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:56:01,387 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 14:56:11,472 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:56:21,609 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:56:31,747 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:56:41,806 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:56:51,864 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:57:01,956 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:57:12,093 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:57:22,194 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:57:32,295 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:57:42,405 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:57:52,544 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:58:01,465 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:58:11,588 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:58:21,648 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:58:31,762 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:58:41,825 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:58:51,937 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:59:02,009 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:59:12,108 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:59:22,186 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:59:32,243 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:59:42,298 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 14:59:52,455 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:00:02,520 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:00:12,584 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:00:22,663 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:00:32,749 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:00:37,115 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:00:37,492 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:00:47,061 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:00:47,323 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:00:56,179 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:00:56,812 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:01:06,570 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:07,116 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:07,425 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:01:17,233 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:19,646 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:19,932 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:01:29,728 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:39,793 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:49,860 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:52,767 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:53,032 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:01:56,224 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:56,335 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:01:59,710 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:01:59,806 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:02:09,785 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:02:19,904 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:02:29,959 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:02:40,042 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:02:50,112 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:00,250 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:10,315 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:20,374 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:30,458 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:34,805 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:35,112 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:03:40,495 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:40,915 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:03:46,947 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:47,242 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:03:57,219 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:58,198 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:03:58,577 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:04:08,309 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:04:18,486 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:04:24,425 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:04:24,722 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:04:27,729 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:04:27,819 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:04:34,563 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:04:34,984 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:04:44,633 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:04:54,735 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:04:59,447 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:05:00,146 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendDocument "HTTP/1.1 200 OK"
# 2026-01-21 15:05:04,774 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:05:04,932 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:05:14,910 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:05:25,048 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:05:35,186 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:05:38,790 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:05:39,085 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:05:42,054 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:05:42,161 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/sendMessage "HTTP/1.1 200 OK"
# 2026-01-21 15:05:52,135 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:06:02,291 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:06:12,403 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:06:22,481 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:06:32,550 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:06:42,611 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:06:52,680 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:07:02,744 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:07:12,799 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:07:22,914 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:07:33,051 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:07:43,114 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:07:53,224 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:08:03,365 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:08:13,472 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:08:23,542 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:08:33,629 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:08:43,706 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:08:53,779 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:09:03,883 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:09:14,020 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
# 2026-01-21 15:09:24,158 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot8588939828:AAEov9bgrKEhrvaQ9qNbuTXRlukqOpkr6dI/getUpdates "HTTP/1.1 200 OK"
